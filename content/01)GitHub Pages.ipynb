# %% [markdown]
# # GitHub Pages and Actions
# ***
# This notebooks is about GitHub Pages and Actions

# %% [markdown]
# ## HTTP
# ***
# HTTP [HyperText Transfer Protocol](https://developer.mozilla.org/en-US/docs/Web/HTTP/Overview) is the main protocol used for getting images, videos, ads etc or any data exchange on the web, HTTP follow a client server protocol which means the client sends a request, client then wait for a response from the server, the server sends the client back the request mostly with a status code of 200 for success ![f1.png](attachment:f1.png)

# %% [markdown]
# HTTP is stateless which mean the server should not retain any state between requests, this is known as a REST [REpresentational State Transfer](https://restfulapi.net/) compliant systems which is how to set apart the client and the server
# ![f2.png](attachment:f2.png)
